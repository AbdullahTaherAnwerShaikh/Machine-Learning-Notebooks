# %%
# !pip install -q kaggle

# %%
import os
os.environ["KAGGLE_API_TOKEN"] = "YOUR_KAGGLE_API_TOKEN"

# %%
# !kaggle datasets list -s "apple orange"
# Out:
# ...
# ref                                                            title                                                  size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -----------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# raykleptzo/classification-data-apples-oranges                  Classification Data -Apples & Oranges                   384  2020-05-02 21:48:14.133000           6422         31  0.8235294
# kipshidze/apple-vs-orange-binary-classification                Apple vs Orange Binary Classification               3415245  2025-04-20 18:06:39.453000           1772         27  1
# karimabdulnabi/fruit-classification10-class                    Fruit classification(10 Class)                     30617656  2022-10-06 23:59:58.393000          21018        153  0.875
# ...

# %%
# !kaggle datasets download kipshidze/apple-vs-orange-binary-classification \
    -p /content/apple_orange \
    --unzip
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/kipshidze/apple-vs-orange-binary-classification
# License(s): MIT
# ...
# 100% 3.26M/3.26M [00:00<00:00, 119MB/s]

# %%
# !find /content/apple_orange -maxdepth 3 -type d
# Out:
# /content/apple_orange
# /content/apple_orange/fruit-dataset
# /content/apple_orange/fruit-dataset/orange
# /content/apple_orange/fruit-dataset/apple

# %%
# !find /content/apple_orange -type f | head -20
# Out:
# /content/apple_orange/fruit-dataset/orange/381.jpeg
# /content/apple_orange/fruit-dataset/orange/249.jpeg
# /content/apple_orange/fruit-dataset/orange/023.jpeg
# /content/apple_orange/fruit-dataset/orange/162.jpeg
# /content/apple_orange/fruit-dataset/orange/236.jpeg
# /content/apple_orange/fruit-dataset/orange/040.jpeg
# /content/apple_orange/fruit-dataset/orange/171.jpeg
# /content/apple_orange/fruit-dataset/orange/304.jpeg
# /content/apple_orange/fruit-dataset/orange/146.jpeg
# /content/apple_orange/fruit-dataset/orange/391.jpeg
# /content/apple_orange/fruit-dataset/orange/086.jpeg
# /content/apple_orange/fruit-dataset/orange/349.jpeg
# /content/apple_orange/fruit-dataset/orange/330.jpeg
# /content/apple_orange/fruit-dataset/orange/024.jpeg
# /content/apple_orange/fruit-dataset/orange/073.jpeg
# /content/apple_orange/fruit-dataset/orange/332.jpeg
# /content/apple_orange/fruit-dataset/orange/285.jpeg
# /content/apple_orange/fruit-dataset/orange/116.jpeg
# ...

# %%
from fastai.vision.all import *

path = Path("/content/apple_orange")


dls = ImageDataLoaders.from_folder(
    path,
    valid_pct = 0.2,
    seed = 15,
    item_tfms = Resize(224)
)

learn = vision_learner(dls, resnet18, metrics = error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 141MB/s]
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
# ...
