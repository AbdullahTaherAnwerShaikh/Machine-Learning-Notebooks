# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/data/horse-or-human.zip
# Out:
# --2026-08-26 14:33:56--  https://storage.googleapis.com/download.tensorflow.org/data/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.24.207, 64.233.170.207, 172.253.118.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.24.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M  19.1MB/s    in 8.3s
#
# 2026-08-26 14:34:05 (17.2 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %%
import zipfile

with zipfile.ZipFile("horse-or-human.zip", "r") as zip_ref:
    zip_ref.extractall("horse-or-human")

# %%
from fastai.vision.all import *

path = Path("horse-or-human")

dls = ImageDataLoaders.from_folder(
    path,
    valid_pct=0.2,
    seed=10,
    item_tfms=Resize(224)
)

learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.389437</td><td>0.000096</td><td>0.000000</td><td>00:07</td></tr></tbody></table></div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.006201</td><td>0.000188</td><td>0.000000</td><td>00:08</td></tr><tr><td>1</td><td>0.005310</td><td>0.000099</td><td>0.000000</td><td>00:07</td></tr></tbody></table></div>

# %%
files = get_image_files(path)

print(files[0])
print(files[0].parent)
print(files[0].parent.name)
# Out:
# horse-or-human/humans/human06-22.png
# horse-or-human/humans
# humans

# %%
print(set(x.parent.name for x in files))
# Out:
# {'humans', 'horses'}
